# %% [markdown]
# <a href="https://colab.research.google.com/github/shajathmsc/Advanced-Python-Programming-Lab-Programs/blob/main/05_csv_analysis_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Name": ["Ali", "Sara", "John"],
    "Age": [20, 21, 22],
    "Mark": [85, 90, 78]
}

df = pd.DataFrame(data)

df.to_csv("students.csv", index=False)

print("students.csv created successfully!")
# Out:
# students.csv created successfully!

# %%
import pandas as pd

data = {
    "Name": ["Ali", "Sara", "John", "Ravi", "Aisha"],
    "Marks": [85, 92, 78, 88, 75]
}

df = pd.DataFrame(data)
df.to_csv("students.csv", index=False)

print("students.csv created successfully!")
# Out:
# students.csv created successfully!

# %%
import pandas as pd

df = pd.read_csv("students.csv")

print("CSV Data:")
print(df)

print("\nFirst 3 Records:")
print(df.head(3))

print("\nAverage Marks:")
print(df["Marks"].mean())

print("\nHighest Marks:")
print(df["Marks"].max())

print("\nStudents scoring above 80:")
print(df[df["Marks"] > 80])
# Out:
# CSV Data:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2   John     78
# 3   Ravi     88
# 4  Aisha     75
#
# First 3 Records:
#    Name  Marks
# 0   Ali     85
# 1  Sara     92
# 2  John     78
#
# Average Marks:
# 83.6
#
# Highest Marks:
# 92
#
# Students scoring above 80:
#    Name  Marks
# 0   Ali     85
# 1  Sara     92
# 3  Ravi     88
