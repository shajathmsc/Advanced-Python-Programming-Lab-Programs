# %% [markdown]
# <a href="https://colab.research.google.com/github/shajathmsc/Advanced-Python-Programming-Lab-Programs/blob/main/07_employee_salary_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Employee": ["Arun", "Bala", "Cathy", "David", "Eva"],
    "Department": ["IT", "HR", "IT", "Finance", "HR"],
    "Salary": [35000, 30000, 45000, 50000, 32000]
}

df = pd.DataFrame(data)

print("Employee Data:")
print(df)

print("\nAverage Salary:")
print(df["Salary"].mean())

print("\nHighest Salary:")
print(df["Salary"].max())

print("\nLowest Salary:")
print(df["Salary"].min())

print("\nEmployees with Salary above 35000:")
print(df[df["Salary"] > 35000])

print("\nAverage Salary by Department:")
print(df.groupby("Department")["Salary"].mean())
# Out:
# Employee Data:
#   Employee Department  Salary
# 0     Arun         IT   35000
# 1     Bala         HR   30000
# 2    Cathy         IT   45000
# 3    David    Finance   50000
# 4      Eva         HR   32000
#
# Average Salary:
# 38400.0
#
# Highest Salary:
# 50000
#
# Lowest Salary:
# 30000
#
# Employees with Salary above 35000:
#   Employee Department  Salary
# 2    Cathy         IT   45000
# 3    David    Finance   50000
#
# Average Salary by Department:
# Department
# Finance    50000.0
# HR         31000.0
# IT         40000.0
# Name: Salary, dtype: float64
